# %%
# Generate all possible pairs of players
num_players=16
pairs = [(i, j,k,t) for i in range(num_players) for j in range(i + 1, num_players) for k in range(i + 2, num_players)for t in range(i + 3, num_players)]

# %%
import itertools
onePlaylist=[]
for combination in itertools.combinations(range(17),4):
            onePlaylist.append(set(combination))
print(len(onePlaylist))
onePlaylist
# Out:
# 2380
# [{0, 1, 2, 3},
#  {0, 1, 2, 4},
#  {0, 1, 2, 5},
#  {0, 1, 2, 6},
#  {0, 1, 2, 7},
#  {0, 1, 2, 8},
#  {0, 1, 2, 9},
#  {0, 1, 2, 10},
#  {0, 1, 2, 11},
#  {0, 1, 2, 12},
#  {0, 1, 2, 13},
#  {0, 1, 2, 14},
#  {0, 1, 2, 15},
#  {0, 1, 2, 16},
#  {0, 1, 3, 4},
#  {0, 1, 3, 5},
#  {0, 1, 3, 6},
#  {0, 1, 3, 7},
#  {0, 1, 3, 8},
#  {0, 1, 3, 9},
#  {0, 1, 3, 10},
#  {0, 1, 3, 11},
#  {0, 1, 3, 12},
#  {0, 1, 3, 13},
#  {0, 1, 3, 14},
#  {0, 1, 3, 15},
#  {0, 1, 3, 16},
#  {0, 1, 4, 5},
#  {0, 1, 4, 6},
#  {0, 1, 4, 7},
#  {0, 1, 4, 8},
#  {0, 1, 4, 9},
#  {0, 1, 4, 10},
#  {0, 1, 4, 11},
#  {0, 1, 4, 12},
#  {0, 1, 4, 13},
#  {0, 1, 4, 14},
#  {0, 1, 4, 15},
#  {0, 1, 4, 16},
#  {0, 1, 5, 6},
#  {0, 1, 5, 7},
#  {0, 1, 5, 8},
#  {0, 1, 5, 9},
#  {0, 1, 5, 10},
#  {0, 1, 5, 11},
#  {0, 1, 5, 12},
#  {0, 1, 5, 13},
#  {0, 1, 5, 14},
#  {0, 1, 5, 15},
#  {0, 1, 5, 16},
#  {0, 1, 6, 7},
#  {0, 1, 6, 8},
#  {0, 1, 6, 9},
#  {0, 1, 6, 10},
#  {0, 1, 6, 11},
#  {0, 1, 6, 12},
# ...

# %%
onePlaylist=[]
for sets1 in onePlaylist:
    for sets2 in onePlaylist:
        intersect=sets1&sets2
        length=len(intersect)
        if (length==4):
            onePlaylist.append(sets1)
        if (length<=1):
            onePlaylist.append(sets2)
    onePlaylist.remove(sets1)

# %%
onePlaylist
# Out:
# [{0, 1, 2, 3},
#  {0, 4, 5, 6},
#  {0, 4, 5, 7},
#  {0, 4, 5, 8},
#  {0, 4, 5, 9},
#  {0, 4, 5, 10},
#  {0, 4, 5, 11},
#  {0, 4, 5, 12},
#  {0, 4, 5, 13},
#  {0, 4, 5, 14},
#  {0, 4, 5, 15},
#  {0, 4, 5, 16},
#  {0, 4, 6, 7},
#  {0, 4, 6, 8},
#  {0, 4, 6, 9},
#  {0, 4, 6, 10},
#  {0, 4, 6, 11},
#  {0, 4, 6, 12},
#  {0, 4, 6, 13},
#  {0, 4, 6, 14},
#  {0, 4, 6, 15},
#  {0, 4, 6, 16},
#  {0, 4, 7, 8},
#  {0, 4, 7, 9},
#  {0, 4, 7, 10},
#  {0, 4, 7, 11},
#  {0, 4, 7, 12},
#  {0, 4, 7, 13},
#  {0, 4, 7, 14},
#  {0, 4, 7, 15},
#  {0, 4, 7, 16},
#  {0, 4, 8, 9},
#  {0, 4, 8, 10},
#  {0, 4, 8, 11},
#  {0, 4, 8, 12},
#  {0, 4, 8, 13},
#  {0, 4, 8, 14},
#  {0, 4, 8, 15},
#  {0, 4, 8, 16},
#  {0, 4, 9, 10},
#  {0, 4, 9, 11},
#  {0, 4, 9, 12},
#  {0, 4, 9, 13},
#  {0, 4, 9, 14},
#  {0, 4, 9, 15},
#  {0, 4, 9, 16},
#  {0, 4, 10, 11},
#  {0, 4, 10, 12},
#  {0, 4, 10, 13},
#  {0, 4, 10, 14},
#  {0, 4, 10, 15},
#  {0, 4, 10, 16},
#  {0, 4, 11, 12},
#  {0, 4, 11, 13},
#  {0, 4, 11, 14},
# ...

# %%
secondPlaylist=[]
for sets1 in onePlaylist:
    for sets2 in onePlaylist:
        intersect=sets1&sets2
        length=len(intersect)
        if (length==4):
            secondPlaylist.append(sets1)
        if (length<=1):
            secondPlaylist.append(sets2)
    onePlaylist.remove(sets1)
